# %% [raw]
# Hierarchical clustering is an unsupervised learning algorithm used for grouping data into clusters, based on their similarity. It is a method of creating a hierarchy of clusters, with each cluster being made up of smaller clusters, until each data point is in its own cluster.
#
# There are two main types of hierarchical clustering: agglomerative and divisive. Agglomerative clustering starts with each data point in its own cluster and then combines the most similar clusters until all the data points are in one cluster. Divisive clustering starts with all the data points in one cluster and then divides the cluster into smaller and smaller clusters until each data point is in its own cluster.
#
# Hierarchical clustering works by creating a dendrogram, which is a tree-like diagram that represents the hierarchy of the clusters. The distance between the clusters is represented by the length of the branches on the dendrogram.
#
# Hierarchical clustering is a popular method for grouping data into clusters, as it can handle large datasets and produces a clear visual representation of the clusters. However, it is sensitive to the choice of similarity measure and may not always produce the optimal clusters. It is also computationally expensive, as it requires calculating the distance between all pairs of data points.
#
# The steps for implementing hierarchical clustering are as follows:
#
# Calculate the distance between each pair of data points: The distance between each pair of data points is calculated using a distance metric such as Euclidean distance.
#
# Merge the closest pairs of data points: The two data points with the smallest distance are merged into a single cluster.
#
# Update the distance matrix: The distance between the newly merged cluster and all other data points or clusters is calculated and added to the distance matrix.
#
# Repeat steps 2 and 3 until all data points are merged into a single cluster: The algorithm continues to merge the closest pairs of data points or clusters until all data points are merged into a single cluster.
#
# Output the final cluster hierarchy: The algorithm outputs a hierarchy of clusters, with the smallest clusters at the bottom and the largest cluster at the top.

# %%
from warnings import filterwarnings
filterwarnings('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("../Data/USArrests.csv").copy()
df.index = df.iloc[:,0]
df = df.iloc[:,1:5]
#del df.index.name
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Unnamed: 0
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
from scipy.cluster.hierarchy import linkage
hc_complete = linkage(df, "complete")
hc_average = linkage(df, "average")
hc_single = linkage(df, "single")

# %%
from scipy.cluster.hierarchy import dendrogram

plt.figure(figsize=(15, 10))
plt.title('Hierarchical Clustering - Dendogram')
plt.xlabel('Indexs')
plt.ylabel('Distance')
dendrogram(
    hc_complete,
    leaf_font_size=10
);

# %%
from scipy.cluster.hierarchy import dendrogram

plt.figure(figsize=(15, 10))
plt.title('Hierarchical Clustering - Dendogram')
plt.xlabel('Indexs')
plt.ylabel('Distance')
dendrogram(
    hc_complete,
    truncate_mode = "lastp",
    p = 4,
    show_contracted = True
);

# %%
from scipy.cluster.hierarchy import dendrogram

plt.figure(figsize=(15, 10))
plt.title('Hierarchical Clustering - Dendogram')
plt.xlabel('Indexs')
plt.ylabel('Distance')
den = dendrogram(
    hc_complete,
    leaf_font_size=10
);

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters = 4,
                                  affinity = "euclidean",
                                  linkage = "ward")

cluster.fit_predict(df)
# Out:
# array([0, 0, 0, 2, 0, 2, 3, 0, 0, 2, 1, 3, 0, 3, 1, 3, 3, 0, 1, 0, 2, 0,
#        1, 0, 2, 3, 3, 0, 1, 2, 0, 0, 0, 1, 3, 2, 2, 3, 2, 0, 1, 2, 2, 3,
#        1, 2, 2, 1, 1, 2], dtype=int64)

# %%
pd.DataFrame({"States" : df.index, "Clusters": cluster.fit_predict(df)})[0:10]
# Out:
#         States  Clusters
# 0      Alabama         0
# 1       Alaska         0
# 2      Arizona         0
# 3     Arkansas         2
# 4   California         0
# 5     Colorado         2
# 6  Connecticut         3
# 7     Delaware         0
# 8      Florida         0
# 9      Georgia         2

# %%
df["Cluster_No"] = cluster.fit_predict(df)

# %%
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape  kume_no  Cluster_No
# Unnamed: 0
# Alabama       13.2      236        58  21.2        0           0
# Alaska        10.0      263        48  44.5        0           0
# Arizona        8.1      294        80  31.0        0           0
# Arkansas       8.8      190        50  19.5        2           2
# California     9.0      276        91  40.6        0           0
