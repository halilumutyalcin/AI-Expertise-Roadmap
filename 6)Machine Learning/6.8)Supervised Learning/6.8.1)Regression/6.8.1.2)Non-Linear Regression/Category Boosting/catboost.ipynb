# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import  GridSearchCV
from sklearn.metrics import mean_squared_error

from warnings import filterwarnings
filterwarnings('ignore')

# %%
data = pd.read_csv("../Data/Hitters.csv")
df = data.copy()
df = df.dropna()
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
# 5    594   169      4    74   51     35     11    4408   1133      19    501
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N
# 5   336     194      A        W      282      421      25   750.0         A

# %% [raw]
# Light CatBoost is a variation of the CatBoost machine learning algorithm that is designed to be more memory efficient and faster to train. It achieves this by using a smaller model size and limiting the number of trees in the model.
#
# CatBoost is a popular gradient boosting algorithm that is known for its ability to handle categorical features and missing values in a dataset. It works by creating a series of decision trees, where each tree is trained to make predictions based on the errors made by previous trees.
#
# Light CatBoost is useful for situations where training time and memory usage are a concern, such as when working with large datasets or when running on a low-powered device. It is also useful for quickly prototyping and testing models, as it can be trained much faster than a full CatBoost model.
#
# Overall, Light CatBoost is a useful tool for improving the efficiency and speed of machine learning model training, particularly in situations where training time and memory usage are a concern.

# %%
dms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
dms.head()
# Out:
#    League_A  League_N  Division_E  Division_W  NewLeague_A  NewLeague_N
# 1         0         1           0           1            0            1
# 2         1         0           0           1            1            0
# 3         0         1           1           0            0            1
# 4         0         1           1           0            0            1
# 5         1         0           0           1            1            0

# %%
X_ = df.drop(["Salary","League","Division","NewLeague"],axis = 1).astype("float64")

# %%
y = df["Salary"]

# %%
X_.head()
# Out:
#    AtBat   Hits  HmRun  Runs   RBI  Walks  Years  CAtBat   CHits  CHmRun  \
# 1  315.0   81.0    7.0  24.0  38.0   39.0   14.0  3449.0   835.0    69.0
# 2  479.0  130.0   18.0  66.0  72.0   76.0    3.0  1624.0   457.0    63.0
# 3  496.0  141.0   20.0  65.0  78.0   37.0   11.0  5628.0  1575.0   225.0
# 4  321.0   87.0   10.0  39.0  42.0   30.0    2.0   396.0   101.0    12.0
# 5  594.0  169.0    4.0  74.0  51.0   35.0   11.0  4408.0  1133.0    19.0
#
#    CRuns   CRBI  CWalks  PutOuts  Assists  Errors
# 1  321.0  414.0   375.0    632.0     43.0    10.0
# 2  224.0  266.0   263.0    880.0     82.0    14.0
# 3  828.0  838.0   354.0    200.0     11.0     3.0
# 4   48.0   46.0    33.0    805.0     40.0     4.0
# 5  501.0  336.0   194.0    282.0    421.0    25.0

# %%
X = pd.concat([X_,dms[['League_N','Division_W','NewLeague_N']]],axis=1)
X.head()
# Out:
#    AtBat   Hits  HmRun  Runs   RBI  Walks  Years  CAtBat   CHits  CHmRun  \
# 1  315.0   81.0    7.0  24.0  38.0   39.0   14.0  3449.0   835.0    69.0
# 2  479.0  130.0   18.0  66.0  72.0   76.0    3.0  1624.0   457.0    63.0
# 3  496.0  141.0   20.0  65.0  78.0   37.0   11.0  5628.0  1575.0   225.0
# 4  321.0   87.0   10.0  39.0  42.0   30.0    2.0   396.0   101.0    12.0
# 5  594.0  169.0    4.0  74.0  51.0   35.0   11.0  4408.0  1133.0    19.0
#
#    CRuns   CRBI  CWalks  PutOuts  Assists  Errors  League_N  Division_W  \
# 1  321.0  414.0   375.0    632.0     43.0    10.0         1           1
# 2  224.0  266.0   263.0    880.0     82.0    14.0         0           1
# 3  828.0  838.0   354.0    200.0     11.0     3.0         1           0
# 4   48.0   46.0    33.0    805.0     40.0     4.0         1           0
# 5  501.0  336.0   194.0    282.0    421.0    25.0         0           1
#
#    NewLeague_N
# 1            1
# 2            0
# 3            1
# 4            1
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from catboost import CatBoostRegressor

# %%
catb = CatBoostRegressor()
catb_model = catb.fit(X_train, y_train)
# Out:
# Learning rate set to 0.031674
# 0:	learn: 437.6430699	total: 137ms	remaining: 2m 16s
# 1:	learn: 431.3923642	total: 138ms	remaining: 1m 8s
# 2:	learn: 424.8820360	total: 139ms	remaining: 46.3s
# 3:	learn: 418.2514904	total: 140ms	remaining: 34.9s
# 4:	learn: 412.6394021	total: 141ms	remaining: 28.1s
# 5:	learn: 406.6247020	total: 142ms	remaining: 23.6s
# 6:	learn: 400.5321206	total: 144ms	remaining: 20.4s
# 7:	learn: 394.6683437	total: 145ms	remaining: 18s
# 8:	learn: 388.2496484	total: 146ms	remaining: 16.1s
# 9:	learn: 382.9448842	total: 147ms	remaining: 14.6s
# 10:	learn: 377.2600080	total: 149ms	remaining: 13.4s
# 11:	learn: 372.4829606	total: 150ms	remaining: 12.3s
# 12:	learn: 366.6823437	total: 151ms	remaining: 11.4s
# 13:	learn: 362.6076230	total: 152ms	remaining: 10.7s
# 14:	learn: 358.0107745	total: 153ms	remaining: 10s
# 15:	learn: 353.2802665	total: 154ms	remaining: 9.46s
# 16:	learn: 348.5646265	total: 155ms	remaining: 8.96s
# ...

# %%
y_pred = catb_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 351.194631344607

# %%
catb_grid = {
    'iterations': [200,500,1000,2000],
    'learning_rate': [0.01, 0.03, 0.05, 0.1],
    'depth': [3,4,5,6,7,8] }

# %%
catb = CatBoostRegressor()
catb_cv_model = GridSearchCV(catb, catb_grid, cv=5, n_jobs = -1, verbose = 2)

# %%
catb_cv_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 480 out of 480 | elapsed:  5.5min finished
# 0:	learn: 422.4143448	total: 1.36ms	remaining: 1.36s
# 1:	learn: 404.1864276	total: 2.7ms	remaining: 1.35s
# 2:	learn: 386.3231718	total: 4.24ms	remaining: 1.41s
# 3:	learn: 370.5548032	total: 5.52ms	remaining: 1.37s
# 4:	learn: 354.9242038	total: 6.9ms	remaining: 1.37s
# 5:	learn: 342.3403984	total: 8.15ms	remaining: 1.35s
# 6:	learn: 328.2370070	total: 9.6ms	remaining: 1.36s
# 7:	learn: 317.5056526	total: 11.7ms	remaining: 1.45s
# 8:	learn: 306.6243511	total: 13.1ms	remaining: 1.44s
# 9:	learn: 297.3147023	total: 14.1ms	remaining: 1.4s
# ...

# %%
catb_cv_model.best_params_
# Out:
# {'depth': 5, 'iterations': 1000, 'learning_rate': 0.1}

# %%
catb_tuned = CatBoostRegressor(iterations = 1000,
                               learning_rate = 0.1,
                               depth = 5)

catb_tuned = catb_tuned.fit(X_train,y_train)
# Out:
# 0:	learn: 422.4143448	total: 1.18ms	remaining: 1.18s
# 1:	learn: 404.1864276	total: 2.09ms	remaining: 1.04s
# 2:	learn: 386.3231718	total: 2.81ms	remaining: 935ms
# 3:	learn: 370.5548032	total: 3.58ms	remaining: 891ms
# 4:	learn: 354.9242038	total: 4.76ms	remaining: 948ms
# 5:	learn: 342.3403984	total: 5.59ms	remaining: 926ms
# 6:	learn: 328.2370070	total: 6.28ms	remaining: 890ms
# 7:	learn: 317.5056526	total: 6.99ms	remaining: 867ms
# 8:	learn: 306.6243511	total: 7.69ms	remaining: 847ms
# 9:	learn: 297.3147023	total: 8.37ms	remaining: 829ms
# 10:	learn: 288.3685892	total: 9.08ms	remaining: 817ms
# 11:	learn: 281.0996220	total: 9.79ms	remaining: 806ms
# 12:	learn: 273.2254898	total: 10.5ms	remaining: 795ms
# 13:	learn: 266.9003385	total: 11.1ms	remaining: 784ms
# 14:	learn: 261.9092500	total: 11.9ms	remaining: 779ms
# 15:	learn: 256.2637350	total: 12.6ms	remaining: 777ms
# 16:	learn: 250.3667935	total: 13.3ms	remaining: 769ms
# 17:	learn: 244.8631098	total: 13.9ms	remaining: 759ms
# ...

# %%
y_pred = catb_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 356.665762904938
