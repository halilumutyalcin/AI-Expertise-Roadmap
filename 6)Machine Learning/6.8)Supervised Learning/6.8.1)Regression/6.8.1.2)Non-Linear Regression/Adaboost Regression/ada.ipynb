# %% [raw]
# Adaboost (Adaptive Boosting) is a machine learning algorithm that is used to improve the accuracy of weak learning algorithms, such as decision trees. It works by iteratively training a series of weak learners on different subsets of the data, and then combining the predictions of these weak learners to create a final, more accurate prediction.
#
# The process of training the weak learners is called boosting, and the algorithm is called Adaboost because it adaptively adjusts the weight of each weak learner based on its accuracy. In each iteration, the weak learner that performs the best on the current subset of the data is given a higher weight, while the weak learners that perform poorly are given a lower weight. This process continues until a desired level of accuracy is reached.
#
# Adaboost is particularly useful when there are many features in the data, as it is able to handle high dimensional data well. It is also useful when the data is noisy or has a high degree of class imbalance, as it is able to handle these situations better than many other machine learning algorithms.
#
# Overall, Adaboost is a powerful tool for improving the accuracy of weak learning algorithms and is commonly used in a variety of applications, including image and speech recognition, natural language processing, and predictive modeling.

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = datasets.load_boston()
X = dataset.data; y = dataset.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
model_ABR = AdaBoostRegressor()
model_ABR.fit(X_train, y_train)
print(model_ABR)
# Out:
# AdaBoostRegressor()

# %%
expected_y  = y_test
predicted_y = model_ABR.predict(X_test)

# %%
print(metrics.r2_score(expected_y, predicted_y))
print(metrics.mean_squared_log_error(expected_y, predicted_y))

plt.figure(figsize=(10,10))
sns.regplot(expected_y, predicted_y, fit_reg=True, scatter_kws={"s": 100});
# Out:
# 0.8638906068277321
# 0.02715385030076997
# C:\Users\Halil Umut Yalcin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
